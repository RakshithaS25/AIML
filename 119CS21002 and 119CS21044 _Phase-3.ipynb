# %% [markdown]
# # Phase-3

# %% [markdown]
# # Exploratory Data Analysis
# Data Exploration and analysis for the stated problem & Given Dataset (Coding)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Admin/Downloads/e333a07c-9d92-4b9a-a856-9eb29055f772.csv')
data
# Out:
#      _id           City     Year  Average No. of daily trips  \
# 0      1           Agra  2015-16                       245.0
# 1      2           Agra  2016-17                       258.0
# 2      3           Agra  2017-18                       217.0
# 3      4         Aizawl  2015-16                         2.5
# 4      5         Aizawl  2016-17                         2.5
# ..   ...            ...      ...                         ...
# 120  121  Visakhapatnam  2016-17                      7667.0
# 121  122  Visakhapatnam  2017-18                      7953.0
# 122  123       Warangal  2015-16                      5377.0
# 123  124       Warangal  2016-17                      6102.0
# 124  125       Warangal  2017-18                      6022.0
#
#      Average No. of passengers (day-to-day basis)  \
# 0                                        20222.00
# 1                                        16392.00
# 2                                        16742.00
# ...

# %%
# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Summary statistics
print(data.describe())
# Out:
#    _id    City     Year  Average No. of daily trips  \
# 0    1    Agra  2015-16                       245.0
# 1    2    Agra  2016-17                       258.0
# 2    3    Agra  2017-18                       217.0
# 3    4  Aizawl  2015-16                         2.5
# 4    5  Aizawl  2016-17                         2.5
#
#    Average No. of passengers (day-to-day basis)  \
# 0                                       20222.0
# 1                                       16392.0
# 2                                       16742.0
# 3                                         200.0
# 4                                         200.0
#
#    Average Trip length in km (daily)  Average cost per km in rupees (daily)  \
# 0                            16546.0                               301632.0
# 1                            15030.0                               273793.0
# 2                            16408.0                               305810.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Average No. of daily trips', data=data)
plt.title('Earnings from Buses Over Time')
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.show()

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 1.    Univariate Analysis

# %%
#1 Summary Statistics:

earnings = data['Average No. of daily trips']
earnings.describe()
# Out:
# count      121.000000
# mean      4167.600248
# std      11392.805362
# min          0.000000
# 25%        174.000000
# 50%        741.000000
# 75%       2416.000000
# max      72315.000000
# Name: Average No. of daily trips, dtype: float64

# %%
#Histogram:

plt.figure(figsize=(8, 6))
plt.hist('Average No. of daily trips', bins=30, edgecolor='k')
plt.title('Earnings Distribution')
plt.xlabel('Earnings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year', y='Revenue per km in rupees', data=data)
plt.title('Revenue per km in rupees')
plt.xlabel('Year')
plt.ylabel('Revenue per km in rupees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Revenue per km in rupees', data=data)
plt.title('Revenue per km in rupees')
plt.xlabel('Year')
plt.ylabel('Revenue per km in rupees')
plt.show()

# %% [markdown]
# # 4. Visualize above with Bar, Box, FacetGrid, Heatmap, Crosstab, Line plot Submission ( Python File with dataset)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Bar Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Average No. of passengers (day-to-day basis)', data=data)
plt.title('Bar Plot of Earnings by Category')
plt.xlabel('Category')
plt.ylabel('Earnings')
plt.show()

# %%
# 2. Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Year', y='Average No. of passengers (day-to-day basis)', data=data)
plt.title('Box Plot of Earnings by Year')
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.show()

# %%
# 3. FacetGrid (Faceted Plot)
g = sns.FacetGrid(data, col='Average No. of daily trips', height=4)
g.map(sns.barplot, 'Year', 'Average No. of passengers (day-to-day basis)', ci=None)
g.set_axis_labels('Year', 'Average No. of passengers (day-to-day basis)')
g.set_titles('Average No. of daily trips: {col_name}')
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle('FacetGrid: Earnings by Year for Different Categories')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# 4. Heatmap
correlation_matrix = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# 5. Crosstab and Heatmap
cross_tab = pd.crosstab(data['Average No. of daily trips'], data['Year'])
plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab, annot=True, cmap='Blues')
plt.title('Crosstab Heatmap: Earnings by Category and Year')
plt.show()

# %%
# 6. Line Plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Average No. of passengers (day-to-day basis)', hue='Average No. of daily trips', data=data)
plt.title('Line Plot of Earnings Over Years by Category')
plt.xlabel('Year')
plt.ylabel('Average No. of passengers (day-to-day basis)')
plt.legend(title='Average No. of daily trips')
plt.show()
